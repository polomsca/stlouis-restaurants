# %% [markdown]
# # St. Louis restaurants
# ## Analysis of food facility inspections
#
# Chances are, if you've eaten out at any point in your life, you might have noticed these signs taped near the restaurant door:

# %%
from IPython.display import Image
Image(url='https://web.archive.org/save/_embed/http://s3-media1.fl.yelpcdn.com/bphoto/02Ov5uDbQFRvFV77mZkwdw/l.jpg', width = 450)
# Out:
# <img src="https://web.archive.org/save/_embed/http://s3-media1.fl.yelpcdn.com/bphoto/02Ov5uDbQFRvFV77mZkwdw/l.jpg" width="450"/>

# %% [markdown]
# For me at least, every restaurant I've gone to has boasted a "Grade A" rating from the St. Louis Department of Health. Of course, that has only made me curious to see whether there are restaurants that have gotten anything lower than an "A".
#
# First, I decided to look up data on restaurant inspections online. Apparently, the St. Louis Department of Health hosts its inspection records with a company called [HealthSpace Informatics](http://www.healthspace.com/about.html). Unfortunately, [their records](http://www.healthspace.com/Clients/Missouri/StLouis/St_Louis_Web_Live.nsf) are not easily accessible if we want to find out if a restaurant can score lower than an "A". So we decided to scape out all the hosted information into an easily parsible JSON,

# %%
import requests
from lxml import html
import time
import json
import fnmatch
from requests.exceptions import ConnectionError

try:
    response = requests.get('http://www.healthspace.com/Clients/Missouri/StLouis/St_Louis_Web_Live.nsf/Food-WardList?OpenView&Count=999&')
except ConnectionError:
	time.sleep(1)
	response = requests.get('http://www.healthspace.com/Clients/Missouri/StLouis/St_Louis_Web_Live.nsf/Food-WardList?OpenView&Count=999&')
parsed_body = html.fromstring(response.text)

ward_link = parsed_body.xpath('//a/@href')
ward_name = parsed_body.xpath('//a/text()')
ward_name[7] = 'append'

ward_list = {}
facility_link_start_list = {}
for i in range(len(ward_link)):
	s = 'http://www.healthspace.com' + ward_link[i]
	try:
		response = requests.get(s)
	except ConnectionError:
		time.sleep(1)
		response = requests.get(s)
	parsed_body = html.fromstring(response.text)
	facility_link_start_list[0] = parsed_body.xpath('//a/@href')

	if 'start=' in facility_link_start_list[0][-1]:
		start = facility_link_start_list[0][-1]
		del facility_link_start_list[0][-1]
		s = 'http://www.healthspace.com/Clients/Missouri/StLouis/St_Louis_Web_Live.nsf/' + start
		try:
			response = requests.get(s)
		except ConnectionError:
			time.sleep(1)
			response = requests.get(s)
		parsed_body = html.fromstring(response.text)
		facility_link_start_list[1] = parsed_body.xpath('//a/@href')
		
		n = 1
		while 'start=' in facility_link_start_list[n][-2]:
			start = facility_link_start_list[n][-1]
			del facility_link_start_list[n][-1]
			del facility_link_start_list[n][-1]
			s = 'http://www.healthspace.com/Clients/Missouri/StLouis/St_Louis_Web_Live.nsf/' + start
			try:
				response = requests.get(s)
			except ConnectionError:
				time.sleep(1)
				response = requests.get(s)
			parsed_body = html.fromstring(response.text)
			n = n + 1
			facility_link_start_list[n] = parsed_body.xpath('//a/@href')

		del facility_link_start_list[n][-1]
	
	facility_link = []
	for n in range(len(facility_link_start_list)):
		facility_link = facility_link + facility_link_start_list[n]
		
	facility_list = {}
	for j in range(len(facility_link)):
		s = 'http://www.healthspace.com' + facility_link[j]
		try:	
			response = requests.get(s)
		except ConnectionError:
			time.sleep(1)
			response = requests.get(s)
		parsed_body = html.fromstring(response.text)

		facility_name = parsed_body.xpath('//h2/text()')
		facility_name = facility_name[0]
		facility_location = parsed_body.xpath('//p/text()') 
		facility_location = facility_location[1].strip('\n')
		
		facility_information = parsed_body.xpath('//td/text()')
		
		facility_type = facility_information[1]
		facility_phone = facility_information[3]
		facility_smoking = facility_information[5]

		facility_inspection_link = parsed_body.xpath('//a/@href')
		del facility_inspection_link[0:2]

		inspection_list = {}
		for k in range(len(facility_inspection_link)):
			s = 'http://www.healthspace.com/Clients/Missouri/StLouis/St_Louis_Web_Live.nsf/' + facility_inspection_link[k]
			try:
				response = requests.get(s)
			except ConnectionError:
				time.sleep(1)
				response = requests.get(s)
			parsed_body = html.fromstring(response.text)
			inspection_information = parsed_body.xpath('//td/text()')
			tagged = parsed_body.xpath('//font/text()')

			for n in range(len(inspection_information)):
				inspection_information[n] = inspection_information[n].replace(u'\xa0', '').encode('utf-8')
				inspection_information[n] = inspection_information[n].strip()

			for n in range(len(tagged)):
				tagged[n] = tagged[n].replace(u'\xa0', '').encode('utf-8')
				tagged[n] = tagged[n].strip()

			dict = {}    
			filtered = fnmatch.filter(inspection_information, '*:')
			for n in range(len(filtered)):
				q = inspection_information.index(filtered[n])     
				if inspection_information[q+1] in filtered:
					inspection_information[q] = inspection_information[q].strip(':')
					dict[inspection_information[q]] = ''      
				else:
					inspection_information[q] = inspection_information[q].strip(':')
					dict[inspection_information[q]] = inspection_information[q+1]

			filtered = fnmatch.filter(inspection_information, '?-???.?? / *')      
			for n in range(len(filtered)):
				q = inspection_information.index(filtered[n])
				dict[inspection_information[q]] = {'Comments' : inspection_information[q+1], 'Tag' : tagged[n]}

			inspection_list[dict['Inspection date']] = dict   
            
		facility_list[facility_name] = {'Facility Name' : facility_name, 'Facility Location' : facility_location, 'Facility Type' : facility_type, 'Phone Number' : facility_phone, 'Smoking Status' : facility_smoking, 'Inspection History' : inspection_list}

	ward_list['Ward ' + ward_name[i]] = facility_list
ward_list['Ward 7'].update(ward_list['Ward append'])
del ward_list['Ward append']
json.dump(ward_list, open("inspections.json", 'w'))

# %% [markdown]
# To find out if any restaurant in the St. Louis area has scored lower than an "A" in recent memory, we will dig through the JSON file to check the "Letter Grade" field for each restaurant's most recent inspection.

# %%
import dateutil.parser as parser
import pandas

a = 0
b = 0
c = 0
d = 0

loaded = json.loads(open('inspections.json').read())
wards = sorted(loaded)
for i in range(len(wards)):
	facilities = sorted(loaded[wards[i]])
	for j in range(len(facilities)):
		information = loaded[wards[i]][facilities[j]]
		inspection = information['Inspection History']
		if inspection == {}:
			pass
		else:	
			list = []
			for k in range(len(inspection)):
				text = sorted(inspection)[k]
				date = (parser.parse(text))
				date = date.isoformat()
				list.append(date)
			key = sorted(inspection)[list.index(max(list))]
			if inspection[key]['Letter Grade'] == 'A':
				a = a + 1
			elif inspection[key]['Letter Grade'] == 'B':
				b = b + 1
			elif inspection[key]['Letter Grade'] == 'C':
				c = c + 1
			else:
				d = d + 1
ratings_df = pandas.DataFrame({'Number of restaurants':[a, b, c, d]}, index = ['A', 'B', 'C', 'N/A'])
ratings_df
# Out:
#      Number of restaurants
# A                    10477
# B                        3
# C                        0
# N/A                      2

# %% [markdown]
# From this, we see that our intuition is correct - a vast majority of St. Louis restaurants have received a "Grade A" rating from the Department of Health during their most recent inspection. We also see that three restaurants have received a "Grade B", and no restaurants received a "Grade C".
#
# This might not make too much sense (after all, what's the point of a grading system if everyone gets the same grade?). But looking again at the site, we find:
#
# > Operations that are given a “B” grade must improve within a relatively short time to avoid further sanctions. Often, downgraded establishments decide to suspend operations until they can regain their “A” rating. Operations with a “C” grade must improve immediately to avoid permanent closure. With “C” ratings, the Health department may insist that operations be suspended until problems are resolved.
#
# So a letter grade of "A" is more of a seal of approval than a rating.
#
# Technically we could stop here, but there are more interesting questions to ask now that we know pretty much every restaurant gets an "A". For example, a fun question would be: What is the worst inspection violation a restaurant can get and still get an "A"?
#
# First off, we notice that the Department of Health does present a couple of guidelines concerning violations and grading:
#
# > Some violations are considered “Critical”, and must be immediately remedied. When 2 of these occur during an inspection, the Grade is dropped to “B” or “C”.
#
# From this, we know that violations can be tagged "Critical" if deemed egregious enough. So to find the worst inspection violation on record for a "Grade A" restaurant, we will parse through our JSON data to find violations tagged as "Critical" and print out their comments. (Of course, our judgment on how "bad" a particular critical violation will be a bit more qualitative).
#
# But first, we need to make a new python dictionary of inspections from only "Grade A" restaurants:

# %%
violations_A = []

for i in range(len(wards)):
	facilities = sorted(loaded[wards[i]])
	for j in range(len(facilities)):
		information = loaded[wards[i]][facilities[j]]
		inspection = information['Inspection History']
		if inspection == {}:
			pass
		else:	
			list = []
			for k in range(len(inspection)):
				text = sorted(inspection)[k]
				date = (parser.parse(text))
				date = date.isoformat()
				list.append(date)
			key = sorted(inspection)[list.index(max(list))]
			if inspection[key]['Letter Grade'] == 'A':
				code = (fnmatch.filter(inspection[key], '?-???.?? / *'))
				if code == []:
					pass
				else:
					comment = inspection[key][code[0]]['Comments']
					tagged = inspection[key][code[0]]['Tag']
					if (code[0], comment, tagged) in violations_A:
						pass
					else:
						violations_A.append((code[0], comment, tagged))
violations_A_df = pandas.DataFrame(sorted(violations_A))
violations_A_df
# Out:
#                                                      0  \
# 0                               2-101.11 / Assignment.
# 1                               2-101.11 / Assignment.
# 2                               2-101.11 / Assignment.
# 3                               2-101.11 / Assignment.
# 4                               2-101.11 / Assignment.
# 5                            2-102.11 / Demonstration.
# 6                2-102.20 / Food Manager Certification
# 7                2-102.20 / Food Manager Certification
# 8                2-102.20 / Food Manager Certification
# 9                2-102.20 / Food Manager Certification
# 10               2-102.20 / Food Manager Certification
# 11               2-102.20 / Food Manager Certification
# 12               2-102.20 / Food Manager Certification
# 13                             2-301.14 / When to Wash
# 14       2-401.11 / Eating, Drinking, or Using Tobacco
# 15       2-401.11 / Eating, Drinking, or Using Tobacco
# ...

# %% [markdown]
# And now we filter out violations labeled as "Critical" or "Critical Repeat".

# %%
violations_A_crit = []

for i in range(len(violations_A)):
	if violations_A[i][2] == 'Critical' or violations_A[i][2] == 'Critical Repeat':
		violations_A_crit.append(violations_A[i])
violations_A_crit_df = pandas.DataFrame(sorted(violations_A_crit))
violations_A_crit_df
# Out:
#                                                      0  \
# 0                               2-101.11 / Assignment.
# 1                               2-101.11 / Assignment.
# 2                               2-101.11 / Assignment.
# 3                               2-101.11 / Assignment.
# 4                               2-101.11 / Assignment.
# 5                            2-102.11 / Demonstration.
# 6                2-102.20 / Food Manager Certification
# 7                2-102.20 / Food Manager Certification
# 8                2-102.20 / Food Manager Certification
# 9                2-102.20 / Food Manager Certification
# 10               2-102.20 / Food Manager Certification
# 11               2-102.20 / Food Manager Certification
# 12               2-102.20 / Food Manager Certification
# 13                             2-301.14 / When to Wash
# 14   3-101.11 / Safe, Unadulterated, and Honestly P...
# 15     3-301.11 / Preventing Contamination from Hands.
# ...

# %% [markdown]
# So I guess the worst that can happen is that the food manager isn't certified and/or displays varying levels of incompetence, the food is improperly grouped with raw meats and/or toxins, the meat isn't held at a high enough temperature or the fruit not at a low enough temperature, the employees don't wash their hands with soap and your food service equipment isn't clean or working. At most, it seems like you could get mild food poisoning from a "Grade A" restaurant.
#
# Now that we have this data, (and roughly know the worst that can happen when we order at a restaurant), we can start asking fun statistical questions like "What are the most frequently shown inspection violations?", and "Are there certain violations more frequently tagged as 'Critical' than other violations?" We can also keep asking qualitative questions like "What is the most innocuous non-critical violation?". Since I've answered my own curiousities about restaurant grades, I'll leave these questions and more to the people who want to keep playing with the data.
